# %%
# %matplotlib inline
from parcels import FieldSet, Field, VectorField, ParticleFile, ParticleSet, JITParticle, AdvectionRK4, AdvectionEE, plotTrajectoriesFile, Variable, BrownianMotion2D
from parcels import ErrorCode
from parcels import rng as random
import numpy as np
import math
from datetime import timedelta, datetime
from operator import attrgetter

# %%
# plot trajectories as histogram, select option

#plotTrajectoriesFile('PassiveFloatRK4.nc', mode='hist2d', bins=[10, 10]); #Histogram of number of particle observations per bin
#plotTrajectoriesFile('PassiveFloatEE.nc', mode='hist2d', bins=[10, 10]); #Histogram of number of particle observations per bin
#plotTrajectoriesFile('KelpFloat.nc', mode='hist2d', bins=[10, 10]); #Histogram of number of particle observations per bin
#plotTrajectoriesFile('KelpFloatSub.nc', mode='hist2d', bins=[10, 10]); #Histogram of number of particle observations per bin
#plotTrajectoriesFile('KelpFloatP05.nc', mode='hist2d', bins=[10, 10]); #Histogram of number of particle observations per bin
#plotTrajectoriesFile('KelpFloatP10.nc', mode='hist2d', bins=[10, 10]); #Histogram of number of particle observations per bin

# %%
# animation

#plotTrajectoriesFile('RK4_PFloat.nc', mode='movie2d_notebook')

#plotTrajectoriesFile('Min_KFloat_H100_W00.nc', mode='movie2d_notebook')
#plotTrajectoriesFile('Min_KFloat_H095_W05.nc', mode='movie2d_notebook')
#plotTrajectoriesFile('Min_KFloat_H090_W10.nc', mode='movie2d_notebook')
#plotTrajectoriesFile('Min_KFloat_H085_W15.nc', mode='movie2d_notebook')

#plotTrajectoriesFile('Mean_KFloat_H100_W00.nc', mode='movie2d_notebook')
#plotTrajectoriesFile('Mean_KFloat_H095_W05.nc', mode='movie2d_notebook')
#plotTrajectoriesFile('Mean_KFloat_H090_W10.nc', mode='movie2d_notebook')
#plotTrajectoriesFile('Mean_KFloat_H085_W15.nc', mode='movie2d_notebook')

#plotTrajectoriesFile('Max_KFloat_H100_W00.nc', mode='movie2d_notebook')
plotTrajectoriesFile('Max_KFloat_H095_W05.nc', mode='movie2d_notebook')
#plotTrajectoriesFile('Max_KFloat_H090_W10.nc', mode='movie2d_notebook')
#plotTrajectoriesFile('Max_KFloat_H085_W15.nc', mode='movie2d_notebook')
# Out:
# C:\Users\Hp\Miniconda3\envs\py3_parcels\lib\site-packages\parcels\scripts\plottrajectoriesfile.py:73: RuntimeWarning: invalid value encountered in less
#   lon[:, p] = [ln if ln < 180 else ln - 360 for ln in lon[:, p]]
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
